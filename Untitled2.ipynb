# %%
conda install pandas numpy scikit-learn fosforml matplotlib
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - fosforml
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fosforml statsmodels
# Out:
# ...
#      |████████████████████████████████| 10.8MB 9.1MB/s eta 0:00:01████▌                       | 2.9MB 9.1MB/s eta 0:00:01MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 235kB 89.7MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 24.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
sf_df = my_session.sql("select * from FDC_RAKESH_DEV.FDC_RAKESH_DEV.ELECTRIC_PRODUCTION")
pandas_df = sf_df.to_pandas()

# %%
plt.figure(figsize=(10, 6))
plt.plot(pandas_df, label='Original Data')
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
pandas_df.head()
# Out:
#          DATE  IPG2211A2N
# 0  1985-01-01     72.5052
# 1  1985-02-01     70.6720
# 2  1985-03-01     62.4502
# 3  1985-04-01     57.4714
# 4  1985-05-01     55.3151

# %%
train_size = int(len(pandas_df) * 0.8)
x_train, x_test = pandas_df.iloc[:train_size], pandas_df.iloc[train_size:]

# %%
y_train = x_train['IPG2211A2N'].to_frame()
x_train.drop('IPG2211A2N', axis=1, inplace=True)
y_test = x_test['IPG2211A2N'].to_frame()
x_test.drop('IPG2211A2N', axis=1, inplace=True)

# %%
y_train.head

# %%
best_model = ARIMA(x_train, order=(5,1,0))
model_fit = best_model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 best_model = ARIMA(x_train, order=(5,1,0))
#       2 model_fit = best_model.fit()
#
# File /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py:158, in ARIMA.__init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151     trend = 'n'
#     153 # Construct the specification
#     154 # (don't pass specific values of enforce stationarity/invertibility,
#     155 # because we don't actually want to restrict the estimators based on
#     156 # this criteria. Instead, we'll just make sure that the parameter
#     157 # estimates from those methods satisfy the criteria.)
# --> 158 self._spec_arima = SARIMAXSpecification(
# ...

# %%
predictions = model_fit.forecast(steps=len(x_test))
predictions = pd.Series(predictions, index=x_test.index)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_train, label='Training Data')
plt.plot(x_test, label='Test Data')
plt.plot(predictions, label='Predicted Data', color='red')
plt.title('ARIMA Model - Time Series Forecasting')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()
